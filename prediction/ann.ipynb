# %% [markdown]
# # Accident severity Prediction with ANN

# %% [markdown]
# ## Load data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dense, Dropout
from keras.optimizers import Adam

# %%
# Load data
data = pd.read_csv('../data/merged_information_clean.csv')

# %%
# Only Car accidents

data = data[data['Vehicle_Type'] == 'Car']

data.shape[0]
# Out:
# 1528540

# %% [markdown]
# ## Drop NaN

# %%
df = data.dropna()

# %%
df
# Out:
#          Unnamed: 0 Accident_Index Accident_Severity        Date   Latitude  \
# 2                 2  200501BS00004            Slight  2005-01-07  51.482442
# 4                 4  200501BS00006            Slight  2005-01-11  51.515540
# 7                 7  200501BS00007            Slight  2005-01-13  51.512695
# 8                 8  200501BS00009            Slight  2005-01-14  51.502260
# 9                 9  200501BS00012            Slight  2005-01-16  51.494902
# ...             ...            ...               ...         ...        ...
# 2058276     2058401  2016984130916            Slight  2016-10-28  55.058998
# 2058277     2058402  2016984130916            Slight  2016-10-28  55.058998
# 2058278     2058403  2016984131116            Slight  2016-11-01  55.005033
# 2058281     2058406  2016984131316            Slight  2016-10-29  54.989597
# 2058282     2058407  2016984133416            Slight  2016-12-25  55.310151
#
#          Longitude       Light_Conditions  Number_of_Casualties  \
# 2        -0.173862               Daylight                     1
# 4        -0.203238               Daylight                     1
# 7        -0.211277  Darkness - lights lit                     1
# 8        -0.187623               Daylight                     2
# 9        -0.182872  Darkness - lights lit                     1
# ...            ...                    ...                   ...
# 2058276  -3.265390  Darkness - lights lit                     1
# 2058277  -3.265390  Darkness - lights lit                     1
# 2058278  -3.312631               Daylight                     2
# 2058281  -3.272584  Darkness - lights lit                     3
# 2058282  -3.448392               Daylight                     2
#
#          Number_of_Vehicles  Speed_limit  ... Age_of_Vehicle      make  \
# 2                         1         30.0  ...            4.0    NISSAN
# 4                         2         30.0  ...            1.0      AUDI
# 7                         2         30.0  ...            4.0  MERCEDES
# 8                         1         30.0  ...           16.0    JAGUAR
# 9                         1         30.0  ...            6.0      FORD
# ...                     ...          ...  ...            ...       ...
# 2058276                   2         30.0  ...            8.0      SEAT
# 2058277                   2         30.0  ...           11.0   RENAULT
# 2058278                   2         60.0  ...           14.0      MINI
# 2058281                   1         40.0  ...           13.0  VAUXHALL
# 2058282                   1         70.0  ...            5.0     MAZDA
#
#                            model Sex_of_Driver Vehicle_Type  \
# 2                 ALMERA SE AUTO        Female          Car
# 4        A4 SPORT CABRIOLET AUTO          Male          Car
# 7                    ML 430 AUTO          Male          Car
# 8          XJ-S CONVERTIBLE AUTO          Male          Car
# 9             MONDEO GHIA X AUTO          Male          Car
# ...                          ...           ...          ...
# 2058276      IBIZA ECOMOTIVE TDI        Female          Car
# 2058277     MEGANE DYNAMIQUE 16V     Not known          Car
# 2058278              MINI COOPER        Female          Car
# 2058281           VECTRA SXI 16V          Male          Car
# 2058282        CX-7 SPORT TECH D          Male          Car
#
#         Hit_Object_in_Carriageway  Hit_Object_off_Carriageway  \
# 2                         No data                     No data
# 4                         No data                     No data
# 7                         No data                     No data
# 8                         No data                     No data
# 9                         No data                     No data
# ...                           ...                         ...
# 2058276            Parked vehicle                     No data
# 2058277                   No data      Other permanent object
# 2058278                   No data                     No data
# 2058281                   No data                        Tree
# 2058282                   No data               Wall or fence
#
#          Vehicle_Manoeuvre Driver_Home_Area_Type X1st_Point_of_Impact
# 2        Going ahead other                 Urban                Front
# 4               Moving off                 Urban       Did not impact
# 7                   Parked                 Urban                 Back
# 8        Going ahead other                 Urban                Front
# 9        Going ahead other                 Urban                Front
# ...                    ...                   ...                  ...
# 2058276  Going ahead other                 Rural                Front
# 2058277             Parked               No data                Front
# 2058278  Going ahead other                 Urban                Front
# 2058281  Going ahead other                 Urban                Front
# 2058282  Going ahead other                 Urban             Nearside
#
# [1320913 rows x 26 columns]

# %% [markdown]
# ## Is the number of each outcomes large enough?

# %%
severity_counts = df['Accident_Severity'].value_counts()

print(severity_counts)
# Out:
# Accident_Severity
# Slight     1159828
# Serious     146639
# Fatal        14446
# Name: count, dtype: int64

# %%
# Select relevant features
features = [
    #"Time",
    "Light_Conditions",
    "Weather_Conditions",
    "Speed_limit",
    "Road_Type",
    "Road_Surface_Conditions",
    "Urban_or_Rural_Area",
    "Age_Band_of_Driver",
    "Sex_of_Driver",
    "Age_of_Vehicle",
    "Vehicle_Manoeuvre"
]


target = 'Accident_Severity'

X = df[features]
y = df[target]

# %%
X.isna().sum()
# Out:
# Light_Conditions           0
# Weather_Conditions         0
# Speed_limit                0
# Road_Type                  0
# Road_Surface_Conditions    0
# Urban_or_Rural_Area        0
# Age_Band_of_Driver         0
# Sex_of_Driver              0
# Age_of_Vehicle             0
# Vehicle_Manoeuvre          0
# dtype: int64

# %%
X
# Out:
#               Light_Conditions     Weather_Conditions  Speed_limit  \
# 2                     Daylight     Fine no high winds         30.0
# 4                     Daylight  Raining no high winds         30.0
# 7        Darkness - lights lit     Fine no high winds         30.0
# 8                     Daylight     Fine no high winds         30.0
# 9        Darkness - lights lit     Fine no high winds         30.0
# ...                        ...                    ...          ...
# 2058276  Darkness - lights lit     Fine no high winds         30.0
# 2058277  Darkness - lights lit     Fine no high winds         30.0
# 2058278               Daylight     Fine no high winds         60.0
# 2058281  Darkness - lights lit     Fine no high winds         40.0
# 2058282               Daylight   Raining + high winds         70.0
#
#                   Road_Type Road_Surface_Conditions Urban_or_Rural_Area  \
# 2        Single carriageway                     Dry               Urban
# 4        Single carriageway             Wet or damp               Urban
# 7        Single carriageway                     Dry               Urban
# 8          Dual carriageway                     Dry               Urban
# 9        Single carriageway                     Dry               Urban
# ...                     ...                     ...                 ...
# 2058276  Single carriageway             Wet or damp               Rural
# 2058277  Single carriageway             Wet or damp               Rural
# 2058278  Single carriageway                     Dry               Rural
# 2058281  Single carriageway                     Dry               Rural
# 2058282    Dual carriageway             Wet or damp               Rural
#
#         Age_Band_of_Driver Sex_of_Driver  Age_of_Vehicle  Vehicle_Manoeuvre
# 2                  46 - 55        Female             4.0  Going ahead other
# 4                  46 - 55          Male             1.0         Moving off
# 7                  36 - 45          Male             4.0             Parked
# 8                  66 - 75          Male            16.0  Going ahead other
# 9                  26 - 35          Male             6.0  Going ahead other
# ...                    ...           ...             ...                ...
# 2058276            46 - 55        Female             8.0  Going ahead other
# 2058277            No data     Not known            11.0             Parked
# 2058278            21 - 25        Female            14.0  Going ahead other
# 2058281            16 - 20          Male            13.0  Going ahead other
# 2058282            46 - 55          Male             5.0  Going ahead other
#
# [1320913 rows x 10 columns]

# %%
# Convert target to numerical categories
severity_mapping = {'Slight': 0, 'Serious': 1, 'Fatal': 2}
y = y.map(severity_mapping)

# Data preprocessing
categorical_features = X.select_dtypes(include=['object', 'category']).columns
numeric_features = X.select_dtypes(include=['int64', 'float64']).columns

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)])

X_processed = preprocessor.fit_transform(X)

# %%
# Convert the sparse matrix to a dense array
X_processed_dense = X_processed.toarray()

# Convert target to categorical
y_categorical = tf.keras.utils.to_categorical(y)

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X_processed_dense, y_categorical, test_size=0.2, random_state=42)

# %%
# Building the ANN model
model = Sequential()
model.add(Dense(64, input_dim=X_processed_dense.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

model.summary()
# Out:
# C:\Users\Jonas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │           4,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,595 (25.76 KB)
#  Trainable params: 6,595 (25.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Number of epochs
epochs = 10

# Learning rate
learning_rate = 0.001

# Compile the model
model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=epochs, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 26419/26419 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step - accuracy: 0.8772 - loss: 0.3932 - val_accuracy: 0.8785 - val_loss: 0.3863
# Epoch 2/10
# 26419/26419 ━━━━━━━━━━━━━━━━━━━━ 34s 1ms/step - accuracy: 0.8771 - loss: 0.3892 - val_accuracy: 0.8785 - val_loss: 0.3858
# Epoch 3/10
# 26419/26419 ━━━━━━━━━━━━━━━━━━━━ 34s 1ms/step - accuracy: 0.8776 - loss: 0.3877 - val_accuracy: 0.8785 - val_loss: 0.3854
# Epoch 4/10
# 26419/26419 ━━━━━━━━━━━━━━━━━━━━ 34s 1ms/step - accuracy: 0.8782 - loss: 0.3851 - val_accuracy: 0.8785 - val_loss: 0.3853
# Epoch 5/10
# 26419/26419 ━━━━━━━━━━━━━━━━━━━━ 35s 1ms/step - accuracy: 0.8778 - loss: 0.3872 - val_accuracy: 0.8785 - val_loss: 0.3851
# Epoch 6/10
# 26419/26419 ━━━━━━━━━━━━━━━━━━━━ 35s 1ms/step - accuracy: 0.8775 - loss: 0.3869 - val_accuracy: 0.8785 - val_loss: 0.3850
# Epoch 7/10
# 26419/26419 ━━━━━━━━━━━━━━━━━━━━ 35s 1ms/step - accuracy: 0.8775 - loss: 0.3868 - val_accuracy: 0.8785 - val_loss: 0.3858
# Epoch 8/10
# 26419/26419 ━━━━━━━━━━━━━━━━━━━━ 35s 1ms/step - accuracy: 0.8777 - loss: 0.3865 - val_accuracy: 0.8785 - val_loss: 0.3861
# Epoch 9/10
# 26419/26419 ━━━━━━━━━━━━━━━━━━━━ 35s 1ms/step - accuracy: 0.8776 - loss: 0.3869 - val_accuracy: 0.8785 - val_loss: 0.3865
# Epoch 10/10
# 26419/26419 ━━━━━━━━━━━━━━━━━━━━ 35s 1ms/step - accuracy: 0.8774 - loss: 0.3870 - val_accuracy: 0.8785 - val_loss: 0.3861

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy}")

# Predictions
y_pred = model.predict(X_test)
# Out:
# 8256/8256 ━━━━━━━━━━━━━━━━━━━━ 8s 933us/step - accuracy: 0.8791 - loss: 0.3863
# Test Accuracy: 0.8788340091705322
# 8256/8256 ━━━━━━━━━━━━━━━━━━━━ 8s 941us/step

# %% [markdown]
# ## Area Under the Curve (AUC) score

# %%
if len(y_pred[0]) > 2:  # Multi-class classification
    from sklearn.metrics import roc_auc_score

    # Calculate AUC score
    auc_score = roc_auc_score(y_test, y_pred, multi_class='ovr')
    print(f"AUC Score: {auc_score}")
# Out:
# AUC Score: 0.705817223827323

# %% [markdown]
# Interpretation of AUC Score:
#
# An AUC score ranges from 0 to 1.
# A score of 0.5 suggests no discrimination (i.e., random guessing).
# A score above 0.7 is generally considered acceptable and indicates that the model has some ability to distinguish between the positive and negative classes.
# A score above 0.8 is considered good, while a score above 0.9 is considered excellent.
